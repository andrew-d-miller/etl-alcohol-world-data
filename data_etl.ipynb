# %%
! pip install sqlalchemy

# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file = "Resources/HappinessAlcoholConsumption.csv"
HappinessAlcoholConsumption_data_df = pd.read_csv(csv_file)
HappinessAlcoholConsumption_data_df.head()
# Out:
#        Country          Region Hemisphere  HappinessScore  HDI  GDP_PerCapita  \
# 0      Denmark  Western Europe      north           7.526  928         53.579
# 1  Switzerland  Western Europe      north           7.509  943         79.866
# 2      Iceland  Western Europe      north           7.501  933         60.530
# 3       Norway  Western Europe      north           7.498  951         70.890
# 4      Finland  Western Europe      north           7.413  918         43.433
#
#    Beer_PerCapita  Spirit_PerCapita  Wine_PerCapita
# 0             224                81             278
# 1             185               100             280
# 2             233                61              78
# 3             169                71             129
# 4             263               133              97

# %%
csv_file = "Resources/gapminder_alcohol.csv"
gapminder_alcohol_data_df = pd.read_csv(csv_file)
gapminder_alcohol_data_df.head()
# Out:
#        country  alcconsumption  incomeperperson  suicideper100th  employrate  \
# 0  Afghanistan            0.03              NaN         6.684385   55.700001
# 1      Albania            7.29      1914.996551         7.699330   51.400002
# 2      Algeria            0.69      2231.993335         4.848770   50.500000
# 3      Andorra           10.17     21943.339900         5.362179         NaN
# 4       Angola            5.57      1381.004268        14.554677   75.699997
#
#    urbanrate
# 0      24.04
# 1      46.72
# 2      65.22
# 3      88.92
# 4      56.70

# %%
csv_file = "Resources/Life Expectancy Data.csv"
LifeExpectancyData_df = pd.read_csv(csv_file)
LifeExpectancyData_df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %% [markdown]
# ### Create new data with select columns

# %%
HappinessAlcoholConsumption_data_df = HappinessAlcoholConsumption_data_df[['Country', 'HappinessScore','GDP_PerCapita']].copy()
HappinessAlcoholConsumption_data_df.head()
# Out:
#        Country  HappinessScore  GDP_PerCapita
# 0      Denmark           7.526         53.579
# 1  Switzerland           7.509         79.866
# 2      Iceland           7.501         60.530
# 3       Norway           7.498         70.890
# 4      Finland           7.413         43.433

# %%
gapminder_alcohol_data_df = gapminder_alcohol_data_df[['country', 'alcconsumption','incomeperperson','suicideper100th', 'employrate']].copy()
gapminder_alcohol_data_df.head()
# Out:
#        country  alcconsumption  incomeperperson  suicideper100th  employrate
# 0  Afghanistan            0.03              NaN         6.684385   55.700001
# 1      Albania            7.29      1914.996551         7.699330   51.400002
# 2      Algeria            0.69      2231.993335         4.848770   50.500000
# 3      Andorra           10.17     21943.339900         5.362179         NaN
# 4       Angola            5.57      1381.004268        14.554677   75.699997

# %%
LifeExpectancyData_df = LifeExpectancyData_df[['Country', 'Year','Status','Life expectancy ', 'Alcohol']].copy()
LifeExpectancyData_df.head()
# Out:
#        Country  Year      Status  Life expectancy   Alcohol
# 0  Afghanistan  2015  Developing              65.0     0.01
# 1  Afghanistan  2014  Developing              59.9     0.01
# 2  Afghanistan  2013  Developing              59.9     0.01
# 3  Afghanistan  2012  Developing              59.5     0.01
# 4  Afghanistan  2011  Developing              59.2     0.01
